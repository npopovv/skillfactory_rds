# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter

# %%
data = pd.read_csv('data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
display(data[data.budget == data.budget.max()]['original_title'])
answer_ls.append(4)
# Out:
# 491    The Warrior's Way
# Name: original_title, dtype: object

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
display(data[data.runtime == data.runtime.max()]['original_title'])
answer_ls.append(2)
# Out:
# 1158    Gods and Generals
# Name: original_title, dtype: object

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
data[data.runtime == data.runtime.min()][['original_title', 'imdb_id']]
answer_ls.append(3)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
display(data.runtime.mean())
answer_ls.append(2)
# Out:
# 109.65343915343915

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
data.describe()['runtime']
# Out:
# count    1890.000000
# mean      109.653439
# std        18.013641
# min        63.000000
# 25%        97.000000
# 50%       106.500000
# 75%       120.000000
# max       214.000000
# Name: runtime, dtype: float64

# %%
answer_ls.append(1)

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data['profit']=data['revenue']-data['budget']

# %%
data[data.profit == data.profit.max()]
# Out:
#        imdb_id  popularity     budget     revenue original_title  \
# 239  tt0499549    9.432768  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_count  vote_average  release_year      profit
# 239        8458           7.1          2009  2544505847

# %%
answer_ls.append(5)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data[data.profit == data.profit.min()]
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year     profit
# 491    12/2/2010          74           6.4          2010 -413912431

# %%
answer_ls.append(2)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
len(data[data.profit > 0])
# Out:
# 1478

# %%
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
data.release_date = pd.to_datetime(data.release_date)
data
# Out:
#         imdb_id  popularity     budget     revenue  \
# 0     tt0369610   32.985763  150000000  1513528810
# 1     tt1392190   28.419936  150000000   378436354
# 2     tt2908446   13.112507  110000000   295238201
# 3     tt2488496   11.173104  200000000  2068178225
# 4     tt2820852    9.335014  190000000  1506249360
# ...         ...         ...        ...         ...
# 1885  tt0120903    0.182246   75000000   157299717
# 1886  tt0192255    0.123920   22000000    13555988
# 1887  tt0131704    0.104908   76000000    35134820
# 1888  tt0162983    0.031018   40000000    36037909
# 1889  tt0163676    0.015997   15000000     5217498
#
#                             original_title  \
# 0                           Jurassic World
# 1                       Mad Max: Fury Road
# 2                                Insurgent
# 3             Star Wars: The Force Awakens
# 4                                Furious 7
# ...                                    ...
# ...

# %%
data[data.release_year == 2008].sort_values(by='profit', ascending=False).head()
# Out:
#        imdb_id  popularity     budget     revenue  \
# 600  tt0468569    8.466668  185000000  1001921825
# 604  tt0367882    3.161670  185000000   786636033
# 608  tt0795421    2.543535   52000000   609841637
# 607  tt0441773    3.036644  130000000   631744560
# 622  tt0448157    1.800286  150000000   624029371
#
#                                         original_title  \
# 600                                    The Dark Knight
# 604  Indiana Jones and the Kingdom of the Crystal S...
# 608                                         Mamma Mia!
# 607                                      Kung Fu Panda
# 622                                            Hancock
#
#                                                   cast  \
# 600  Christian Bale|Michael Caine|Heath Ledger|Aaro...
# 604  Harrison Ford|Cate Blanchett|Shia LaBeouf|Ray ...
# 608  Meryl Streep|Pierce Brosnan|Amanda Seyfried|Co...
# 607  Jack Black|Dustin Hoffman|Angelina Jolie|Jacki...
# ...

# %%
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
data[(data.release_year >= 2012) & (data.release_year <= 2014) ].sort_values(by='profit', ascending=True)[['profit', 'imdb_id', 'original_title', 'release_year']]
# Out:
#           profit    imdb_id                   original_title  release_year
# 1246  -165710090  tt1210819                  The Lone Ranger          2013
# 1215   -68351500  tt0790736                         R.I.P.D.          2013
# 1008   -51893525  tt1374992                      Upside Down          2012
# 1303   -51337973  tt0884726  Legends of Oz: Dorothy's Return          2013
# 1236   -45510171  tt1308729               Bullet to the Head          2013
# ...          ...        ...                              ...           ...
# 1190   894761885  tt1690953                  Despicable Me 2          2013
# 975    908561013  tt1074638                          Skyfall          2012
# 1181  1015439994  tt1300854                       Iron Man 3          2013
# 1178  1124219009  tt2294629                           Frozen          2013
# 971   1299557910  tt0848228                     The Avengers          2012
#
# [367 rows x 4 columns]

# %%
answer_ls.append(5)

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
genres=[]
for i in data.genres:
    for k in i.split('|'):
        genres.append(k)

# %%
genres = pd.Series(genres)

# %%
genres.value_counts()
# Out:
# Drama              782
# Comedy             683
# Thriller           597
# Action             583
# Adventure          416
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            223
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             20
# Documentary          8
# Foreign              2
# dtype: int64

# %%
answer_ls.append(3)

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
pos_pf = data[data.profit>0]

# %%
(pd.DataFrame(pos_pf.genres.str.split('|').to_list()).stack()).value_counts()
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
(pd.DataFrame(data.director.str.split('|').to_list()).stack()).value_counts()
# Out:
# Steven Soderbergh     13
# Clint Eastwood        12
# Ridley Scott          12
# Robert Rodriguez      11
# Shawn Levy            10
#                       ..
# Dan St. Pierre         1
# Susanna White          1
# Christian Duguay       1
# Juan Diego Solanas     1
# Troy Nixey             1
# Length: 998, dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
(pd.DataFrame(pos_pf.director.str.split('|').to_list()).stack()).value_counts()
# Out:
# Ridley Scott         12
# Steven Soderbergh    10
# Steven Spielberg     10
# Clint Eastwood       10
# Shawn Levy            9
#                      ..
# Don Mancini           1
# Stiles White          1
# Seth Rogen            1
# Steve Hickner         1
# Dustin Hoffman        1
# Length: 814, dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
# сделаем вид, что на каждый фильм приходится один режиссер
data.groupby(['director'])['profit'].sum().sort_values(ascending = False)
# Out:
# director
# Peter Jackson            5202593685
# David Yates              3379295625
# Christopher Nolan        3162548502
# J.J. Abrams              2839169916
# Michael Bay              2760938960
#                             ...
# David Bowers|Sam Fell     -84540684
# Peter Hyams               -86956545
# Ron Underwood             -92896027
# James L. Brooks           -96289726
# Sngmoo Lee               -413912431
# Name: profit, Length: 958, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
import collections
cntr = collections.Counter()
for i in range(len(data)):
    for k in data.loc[i]['cast'].split('|'):
        cntr[k]+=data.profit[i]
cntr.most_common(1)
# Out:
# [('Emma Watson', 6666245597)]

# %%
answer_ls.append(1)

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
new_data = data[data.release_year==2012]
new_data.index = range(len(new_data))

# %%
d = collections.Counter()
for i in range(len(new_data)):
    for k in new_data.loc[i]['cast'].split('|'):
        d[k] += new_data.profit[i]
d.most_common()[-1:]
# Out:
# [('Kirsten Dunst', -68109207)]

# %%
answer_ls.append(3)

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
h_bgt = data[data.budget > data.budget.mean()]

# %%
pd.DataFrame(h_bgt.cast.str.split('|').to_list()).stack().value_counts()
# Out:
# Matt Damon           18
# Adam Sandler         17
# Angelina Jolie       16
# Tom Cruise           15
# Samuel L. Jackson    15
#                      ..
# Philip Winchester     1
# Willow Smith          1
# Ellen Page            1
# Kim Dickens           1
# James D'Arcy          1
# Length: 1508, dtype: int64

# %%
answer_ls.append(3)

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
n_c = data[data.cast.str.contains('Nicolas Cage')]
Counter(pd.DataFrame(n_c.genres.str.split('|').to_list()).stack()).most_common(1)
# Out:
# [('Action', 17)]

# %%
answer_ls.append(2)

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
(pd.DataFrame(data.production_companies.str.split('|').to_list()).stack()).value_counts()
# Out:
# Universal Pictures                               173
# Warner Bros.                                     168
# Paramount Pictures                               122
# Columbia Pictures                                117
# Twentieth Century Fox Film Corporation           109
#                                                 ...
# Big Beach Productions                              1
# Silver Bullet Productions (II)                     1
# Gidden Media                                       1
# Motion Picture Production GmbH & Co. Erste KG      1
# Collision Entertainment                            1
# Length: 1772, dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
(pd.DataFrame(data[data.release_year==2015].production_companies.str.split('|').to_list()).stack()).value_counts()
# Out:
# Warner Bros.                              12
# Universal Pictures                        10
# Twentieth Century Fox Film Corporation     8
# Paramount Pictures                         7
# Columbia Pictures                          7
#                                           ..
# A113                                       1
# Wigram Productions                         1
# Point Grey Pictures                        1
# ImageMovers                                1
# Living Films                               1
# Length: 246, dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
# Неизвестно, как студии делили между собой деньги
cmds = data[data.genres.str.contains('Comedy')]
cmds.index = range(len(cmds))
c = collections.Counter()
for i in range (len(cmds)):
    for k in cmds.production_companies[i].split('|'):
        c[k] += cmds.profit[i]
c.most_common(1)
# Out:
# [('Universal Pictures', 8961545581)]

# %%
answer_ls.append(2)

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
twtw = data[data.release_year == 2012]
twtw.index = range(111)
c = collections.Counter()
for i in range (111):
    for k in twtw.production_companies[i].split('|'):
        c[k] += twtw.profit[i]
c.most_common(1)
# Out:
# [('Columbia Pictures', 2501406608)]

# %%
answer_ls.append(3)

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
pmnt = data[data.production_companies.str.contains('Paramount Pictures')]
pmnt[pmnt.profit == pmnt.profit.min()]['original_title']
# Out:
# 926    K-19: The Widowmaker
# Name: original_title, dtype: object

# %%
answer_ls.append(1)

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
data.groupby('release_year')['profit'].sum().sort_values(ascending = False)
# Out:
# release_year
# 2015    18668572378
# 2014    16397812953
# 2012    16077001687
# 2013    15243179791
# 2011    14730241341
# 2009    13423744372
# 2010    13117292530
# 2008    11663881990
# 2007    11565911801
# 2004     9634180720
# 2003     9228823312
# 2002     9002361487
# 2005     8981925558
# 2006     8691077320
# 2001     7950614865
# 2000     6101399805
# Name: profit, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
# Наверно, не очень хорошо создавать столько вспомагательных массивов?
w_brs = data[data.production_companies.str.contains('Warner Bros')]
w_brs.groupby(['release_year'])['profit'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
data['release_month'] = pd.to_datetime(data.release_date).apply(lambda x: x.month)
data.groupby(['release_month'])['original_title'].count().sort_values(ascending=False)
# Out:
# release_month
# 9     227
# 12    191
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: original_title, dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
len(data[data.release_month.isin([6, 7, 8])])
# Out:
# 450

# %%
answer_ls.append(2)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
data[data.release_month.isin([1,2,12])].groupby('director')['original_title'].count().sort_values(ascending=False)
# Out:
# director
# Peter Jackson                    7
# Clint Eastwood                   6
# Steven Soderbergh                6
# Shawn Levy                       4
# Adam Shankman                    4
#                                 ..
# Matt Reeves                      1
# Matthew O'Callaghan              1
# Matthew Vaughn                   1
# McG                              1
# Aaron Seltzer|Jason Friedberg    1
# Name: original_title, Length: 333, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
pivot = data.pivot_table(values = 'profit', index = 'release_month', columns = 'release_year', aggfunc='sum')
pivot
# Out:
# release_year         2000        2001        2002        2003        2004  \
# release_month
# 1               -26344591   127876758    13657034   145423503   223449403
# 2               310137593   178360689   557847442   422979087   727540831
# 3               490709929   396218262   832386092   160261385   307233119
# 4               124362846   659725033   343737203   479653942   275005057
# 5              1382722190   767934975  1421928692  2000292657  2412578839
# 6               517315528   780612105   747704475   406445507  1294266591
# 7               563809888   873718941   629306797  1356384641   834850950
# 8               264018332   726979609   579318434   444992536   332763539
# 9               175306761    21874909   417267245   503313816   475369751
# 10              399938512   146204533   420527680   837090991   593314410
# 11              487934818  1567240927  1190606216   609390731  1050846495
# ...

# %%
c = collections.Counter()
for i in pivot.columns:
    c[pivot[i].argmax()+1]+=1
c.most_common(1)
# Out:
# [(6, 7)]

# %%
answer_ls.append(2)

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
b = collections.Counter()
c = collections.Counter()
data.index = range(len(data))
for i in data.index:
    for k in data['production_companies'][i].split('|'):
        c[k] += len(data['original_title'][i])
        b[k] += 1
mean = pd.Series(c)/pd.Series(b)
mean.sort_values(ascending = False)
# Out:
# Four By Two Productions       83.0
# Jim Henson Company, The       59.0
# Dos Corazones                 47.0
# Polsky Films                  46.0
# Museum Canada Productions     46.0
#                               ...
# Berlanti Productions           3.0
# Everest Entertainment          3.0
# XM2 Productions                2.0
# Global Entertainment Group     2.0
# Ixtlan Productions             2.0
# Length: 1772, dtype: float64

# %%
answer_ls.append(5)

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
b = collections.Counter()
c = collections.Counter()
for i in data.index:
    for k in data['production_companies'][i].split('|'):
        c[k] += len(data['original_title'][i].split())
        b[k] += 1
mean = pd.Series(c)/pd.Series(b)
mean.sort_values()
# Out:
# Sighvatsson Films           1.0
# Defiance Productions        1.0
# Scout Productions           1.0
# Lietuvos Kinostudija        1.0
# Furst Films                 1.0
#                            ...
# Dos Corazones               9.0
# Polsky Films                9.0
# The Saul Zaentz Company     9.0
# Jim Henson Company, The    10.0
# Four By Two Productions    12.0
# Length: 1772, dtype: float64

# %%
answer_ls.append(5)

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
c = collections.Counter()
for i in data.index:
    for k in data['original_title'][i].lower().split():
        c[k] += 1
len(c)
# Out:
# 2461

# %%
answer_ls.append(3)

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
data[data.vote_average > data.quantile(q=0.99)['vote_average']]['original_title']
# Out:
# 9                                          Inside Out
# 34                                               Room
# 118                                      Interstellar
# 119                           Guardians of the Galaxy
# 125                                The Imitation Game
# 128                                         Gone Girl
# 138                          The Grand Budapest Hotel
# 370                                         Inception
# 600                                   The Dark Knight
# 873                                       The Pianist
# 1082    The Lord of the Rings: The Return of the King
# 1184                          The Wolf of Wall Street
# 1192                                 12 Years a Slave
# 1801                                          Memento
# Name: original_title, dtype: object

# %%
answer_ls.append(1)

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
import itertools
import collections

# %%
actors=collections.Counter()
for i, d in data.iterrows():
    a = d.cast.split('|')
    actors.update([ x for x in itertools.combinations(a, 2)])
actors.most_common(3)
# Out:
# [(('Daniel Radcliffe', 'Rupert Grint'), 8),
#  (('Daniel Radcliffe', 'Emma Watson'), 8),
#  (('Rupert Grint', 'Emma Watson'), 7)]

# %%
answer_ls.append(5)

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
directrs_films = []
for index,f in data.iterrows():
    for d in f.director.split('|'):
        directrs_films += [(f.imdb_id, d)]
directors_df = pd.DataFrame(directrs_films, columns=['imdb_id', 'single_director'])
directors_df.describe()
# Out:
#           imdb_id    single_director
# count        2054               2054
# unique       1890                998
# top     tt1333125  Steven Soderbergh
# freq           12                 13

# %%
count_y = lambda x: len([ i for i in x if i  > 0])
count_n = lambda x: len([ i for i in x if i <= 0])
data['profit_y'] = data['profit']
data['profit_n'] = data['profit']
filter=['Quentin Tarantino', 'Steven Soderbergh', 'Robert Rodriguez', 'Christopher Nolan', 'Clint Eastwood']
res=directors_df.merge(data, on='imdb_id').groupby('single_director').aggregate({"imdb_id": len, "profit_y": count_y, "profit_n": count_n})
res['p'] = res.profit_y / res.imdb_id
res.sort_values(by='p', ascending=False)
res.reset_index(inplace=True)
res[res.single_director.isin(filter)].sort_values(by='p', ascending=False)
# Out:
#        single_director  imdb_id  profit_y  profit_n         p
# 151  Christopher Nolan        8         8         0  1.000000
# 748  Quentin Tarantino        7         6         1  0.857143
# 157     Clint Eastwood       12        10         2  0.833333
# 902  Steven Soderbergh       13        10         3  0.769231
# 791   Robert Rodriguez       11         8         3  0.727273

# %%
answer_ls.append(4)

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       3
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       3
# 11  12       1
# 12  13       1
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       3
# 18  19       2
# 19  20       1
# 20  21       4
# 21  22       2
# 22  23       3
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       2
# 30  31       5
# 31  32       5
# 32  33       3
# 33  34       1
# 34  35       5
# 35  36       4
